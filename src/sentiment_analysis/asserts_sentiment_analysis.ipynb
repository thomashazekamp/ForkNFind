# %% [markdown]
# # Using Asserts to test sentiment Analysis working functionality

# %%
# pick random 30 pieces of data from the yelp dataset
import pandas as pd

def random_select():
    df = pd.read_csv('dataset/yelp_data/updated_yelp_polarity_train.csv')
    df = df.head(3) # pick top 3 rows
    df.to_csv('dataset/yelp_data/top_3_train.csv', index=False) # save random 30 data to new csv file
    return df

# %%
df = random_select()

# %%
def assert_row(given_text, expected_sentiment): # test the sentiment analysis model
    from runner_sent_analysis import predict_sentiment

    pred_sent = predict_sentiment(given_text)

    # Testing that the sentiment analysis model works by producing a '1' or '0'
    print("Running (functionality checks) asserts for sentiment analysis model...")
    assert pred_sent in ['1', '0']
    print("Test passed.")

    # Testing that the sentiment analysis model works by producing the expected sentiment
    print("Running (testing model - returning expected sentiment) asserts for sentiment analysis model...")
    if expected_sentiment == 'positive':
        assert pred_sent == '1'
    elif expected_sentiment == 'negative':
        assert pred_sent == '0'
    print("Test passed.")

# %%
# Running the asserts on each row of the selected dataset
for row in df.itertuples():
    text = row.text
    sentiment = row.sentiment
    assert_row(text, sentiment)
# Out:
# Running model...
# Vectorization type: tfidf
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 5
#       3 text = row.text
#       4 sentiment = row.sentiment
# ----> 5 assert_row(text, sentiment)
#
# Cell In[67], line 4, in assert_row(given_text, expected_sentiment)
#       1 def assert_row(given_text, expected_sentiment): # test the sentiment analysis model
#       2     from runner_sent_analysis import predict_sentiment
# ----> 4     pred_sent = predict_sentiment(given_text)
#       6     # Testing that the sentiment analysis model works by producing a '1' or '0'
#       7     print("Running (functionality checks) asserts for sentiment analysis model...")
#
# File ~/Desktop/CASE4/CA400/2024-ca400-hazekat2-dalye54/src/sentiment_analysis/runner_sent_analysis.py:24, in predict_sentiment(text, vectorization_type)
#      23 def predict_sentiment(text, vectorization_type='tfidf'):
# ---> 24     model, text_trans = run_model(vectorization_type) # returns the model and the text transformer, can have input such as: 'cv' or 'tfidf' (uses tfidf as default option) to choose which vectorization type to use
#      26     processed_text = process_text(text) # process the text - remove links, convert emojis to text, remove hashtags, make string lowercase, remove repeated characters and punctuation and replace contractions
#      27     new_text = text_trans.transform([processed_text]) # transform the processed text - using the text transformer
#
# File ~/Desktop/CASE4/CA400/2024-ca400-hazekat2-dalye54/src/sentiment_analysis/models_processing.py:22, in run_model(vectorization_type)
#      19 print('Running model...')
#      20 print('Vectorization type:', vectorization_type)
# ---> 22 x, y = process_data() # calls process data with x and y being the text tokens and sentiment of the text
#      23 corpus = x # corpus is the text tokens of whole dataset
#      25 # BAG OF WORDS (CountVectorizer)
#
# File ~/Desktop/CASE4/CA400/2024-ca400-hazekat2-dalye54/src/sentiment_analysis/runner_sent_analysis.py:12, in process_data()
#      10 def process_data():
#      11     # Read dataset
# ---> 12     df = read_dataset()
#      14     # Apply text processing and modifications to the dataset
#      15     df = apply_dataset_column_modifications(df)
#
# File ~/Desktop/CASE4/CA400/2024-ca400-hazekat2-dalye54/src/sentiment_analysis/dataset_worker.py:14, in read_dataset()
#      11 def read_dataset():
#      12     # Read in the data
#      13     dataset = 'dataset/yelp_data/updated_yelp_polarity_train.csv'
# ---> 14     df = pd.read_csv(dataset)
#      15     df = df.head(5000) # Limiting the dataset to a number of rows for memory purposes
#      17     return df
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/yelp_review_polarity_dataset/updated_yelp_polarity_train.csv'
